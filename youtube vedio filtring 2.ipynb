# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\HP\Dropbox\MSCBA_THIRD_SEM\MINOR_PROJECT\Video_details.xlsx")
df
# Out:
#    Upload Date Upload Time                                              Title  \
# 0   2023-06-17   12:00:25Z                    This Cigar Is Actually A Vape!!
# 1   2023-06-22   23:32:23Z  FDA warns retailers to stop selling illegal e-...
# 2   2023-10-08   19:15:00Z                Smoking vs Vaping - Which Is Worse?
# 3   2023-05-30   15:00:47Z   Vaping: What are the medical impacts? - BBC News
# 4   2023-05-19   16:00:05Z  Elf Bar Cigalike: Ultimate Convenience in Vapi...
# ..         ...         ...                                                ...
# 56  2023-05-18   16:30:09Z                               Smok Nord C Pod Mod!
# 57  2023-05-28   19:57:20Z  This Vape Pod Is Built For Flavor🤤 #shorts #un...
# 58  2023-09-15   14:19:17Z  Is Vaping Legal? | Are Vapes, E-Cigarettes & E...
# 59  2023-10-27   10:04:00Z  Vaping and oral health: Unveiling the hidden r...
# 60  2023-11-24   14:11:28Z  Tobacco Bill | Parliament seeks to regulate va...
#
# ...

# %%
df.Country.value_counts()
# Out:
# United Kingdom    29
# United States     16
# Not Mentioned      7
# India              3
# Canada             2
# Australia          1
# Philippines        1
# France             1
# South Africa       1
# Name: Country, dtype: int64

# %%
filtered_data = df[df['Country'] == 'India']
filtered_data
# Out:
#    Upload Date Upload Time                                              Title  \
# 6   2023-05-05   13:55:06Z          I BET you did not know this about VAPES!!
# 11  2022-12-21   06:36:06Z  Vapes are better than cigarettes? | Nutshell S...
# 58  2023-09-15   14:19:17Z  Is Vaping Legal? | Are Vapes, E-Cigarettes & E...
#
#       Views  Likes Duration  Comment Count  \
# 6   1058174  39372  PT8M45S           1987
# 11   697530  24506    PT28S            502
# 58     2667     66    PT21S              4
#
#                                      Video Link Country
# 6   https://www.youtube.com/watch?v=3OdhkziNH70   India
# 11  https://www.youtube.com/watch?v=K_mc2r3SWg0   India
# 58  https://www.youtube.com/watch?v=1if3-UViv6I   India

# %%
df["Video Link"].value_counts()
# Out:
# https://www.youtube.com/watch?v=VsfNpOSw-OM    1
# https://www.youtube.com/watch?v=B28Dr_85X1E    1
# https://www.youtube.com/watch?v=1YfmdOudptY    1
# https://www.youtube.com/watch?v=CkVVKLl902Y    1
# https://www.youtube.com/watch?v=zDzK8uu7dm8    1
#                                               ..
# https://www.youtube.com/watch?v=zs8c1G-ZEd8    1
# https://www.youtube.com/watch?v=gj0gmX2wYoM    1
# https://www.youtube.com/watch?v=bfd5O5zrvmw    1
# https://www.youtube.com/watch?v=TbR2IqEAwaU    1
# https://www.youtube.com/watch?v=xuJBV9CjIDc    1
# Name: Video Link, Length: 61, dtype: int64

# %%
k
# Out:
# https://www.youtube.com/watch?v=VsfNpOSw-OM    1
# https://www.youtube.com/watch?v=B28Dr_85X1E    1
# https://www.youtube.com/watch?v=1YfmdOudptY    1
# https://www.youtube.com/watch?v=CkVVKLl902Y    1
# https://www.youtube.com/watch?v=zDzK8uu7dm8    1
#                                               ..
# https://www.youtube.com/watch?v=zs8c1G-ZEd8    1
# https://www.youtube.com/watch?v=gj0gmX2wYoM    1
# https://www.youtube.com/watch?v=bfd5O5zrvmw    1
# https://www.youtube.com/watch?v=TbR2IqEAwaU    1
# https://www.youtube.com/watch?v=xuJBV9CjIDc    1
# Name: Video Link, Length: 61, dtype: int64
